# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
import os

# mount drive
drive.mount('/content/drive')
# define path
path = '/content/drive/MyDrive'
# change working directory
os.chdir(path)
# clone github repo
# !git clone 'https://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@github.com/tuboa2/hydromind.git'

# %% [markdown]
# ### Change Working Directory

# %%
os.chdir(os.path.join(path, 'hydromind/scripts'))

# %% [markdown]
# ### Execute Pipeline

# %%
import gen_data

gen_data.run()
