# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
import sys
import os

# mount drive
drive.mount('/content/drive')
# define path
path = '/content/drive/MyDrive/hydromind'
# add the scripts
sys.path.append(os.path.join(path, 'scripts'))
# change working directory
os.chdir(os.path.join(path, 'scripts/ul'))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Execute Pipeline

# %%
import gen_data

gen_data.run()
# Out:
# /content/drive/MyDrive/hydromind
